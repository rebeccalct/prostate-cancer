# %%
#Load libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from pandas import read_csv
from pandas import set_option
from matplotlib import pyplot
from pandas import read_csv
from pandas import set_option
from matplotlib import pyplot as plt
import seaborn
import os
from rdt.transformers.categorical import OrderedLabelEncoder

# %%
os.chdir("C:/Users/27261/Desktop/prostate/code-0126")

# %% [markdown]
# ## 1. Load the dataset

# %%
dataset1 = pd.read_excel("Dataset_cedric/cedric_database2.xlsx")
dataset1['cT(MRI)'] = dataset1['cT(MRI)'].astype(str)
dataset1
# Out:
#      eadnr (I)        Age cT(MRI)  Multifocaal  \
# 0     89869416  45.408219      2a            0
# 1     89208722  72.849315      2a            0
# 2     88443783  60.191781      3a            1
# 3     88426499  66.857534      3a            0
# 4     88408455  72.002740      3a            1
# ..         ...        ...     ...          ...
# 287   60261557  60.890411      3a            0
# 288   60260249  63.279452      3a            0
# 289   60252811  51.356164      2a            1
# 290   60097736  58.643836       4            0
# 291   60070627  57.101370      3b            0
#
#      1c (0) - Perifeer (1) -  Beide (2) - Transitie (3)  Preoperatief PSA  \
# 0                                                    1               2.64
# 1                                                    3              11.04
# 2                                                    2              15.00
# 3                                                    1               3.50
# 4                                                    1              19.80
# ..                                                 ...                ...
# 287                                                  1              10.60
# 288                                                  1               4.66
# 289                                                  1               7.11
# 290                                                  1               7.50
# 291                                                  1              34.20
#
#      Aantal zones positive percentage  Primaire Gleason  Secundaire Gleason  \
# 0                            1.000000                 3                   4
# 1                            0.333333                 3                   4
# 2                            0.833333                 3                   3
# 3                            0.666667                 3                   4
# 4                            0.250000                 4                   4
# ..                                ...               ...                 ...
# 287                          0.100000                 4                   4
# 288                          0.181818                 4                   4
# 289                          0.500000                 3                   4
# 290                          0.500000                 3                   4
# 291                          0.700000                 4                   5
#
#      Grade group (highest)  Target biopsie Core length (perc)  \
# 0                        2                               64.3
# 1                        2                               50.0
# 2                        1                               75.0
# 3                        2                               91.0
# 4                        4                               83.0
# ..                     ...                                ...
# 287                      4                               30.0
# 288                      4                               60.0
# 289                      2                               54.0
# 290                      2                               73.0
# 291                      5                               92.0
#
#      Target biopsie Core length (mm)  TargetBiopsie Primaire Gleason  \
# 0                                9.0                               3
# 1                                2.0                               3
# 2                                3.0                               3
# 3                               10.0                               3
# 4                                9.0                               4
# ..                               ...                             ...
# 287                              4.0                               4
# 288                              9.0                               4
# 289                              7.0                               3
# 290                              8.0                               3
# 291                             11.0                               4
#
#      Target Biopsie Secundaire Gleason  Grade Group (longest)  \
# 0                                    4                      2
# 1                                    4                      2
# 2                                    3                      1
# 3                                    4                      2
# 4                                    4                      4
# ..                                 ...                    ...
# 287                                  4                      4
# 288                                  4                      4
# 289                                  4                      2
# 290                                  4                      2
# 291                                  5                      5
#
#      Totaal Cilinders hoogste Graad  Percentage Cilinders hoogste graad  \
# 0                                 2                            1.000000
# 1                                 3                            0.428571
# 2                                 2                            0.666667
# 3                                 4                            0.800000
# 4                                 4                            0.571429
# ..                              ...                                 ...
# 287                               3                            0.166667
# 288                               2                            0.181818
# 289                               4                            0.307692
# 290                               8                            0.615385
# 291                               2                            0.181818
#
#      Totaal positieve cilinders  Percentage positieve cilinders  \
# 0                             2                        1.000000
# 1                             3                        0.428571
# 2                             2                        0.666667
# 3                             4                        0.800000
# 4                             4                        0.571429
# ..                          ...                             ...
# 287                           3                        0.166667
# 288                           2                        0.181818
# 289                           6                        0.461538
# 290                           8                        0.615385
# 291                           8                        0.727273
#
#      Percentage Cilinders lagere graad    Aantal cilinders neg+pos  \
# 0                               0.000000                         2
# 1                               0.000000                         7
# 2                               0.000000                         3
# 3                               0.000000                         5
# 4                               0.000000                         7
# ..                                   ...                       ...
# 287                             0.000000                        18
# 288                             0.000000                        11
# 289                             0.153846                        13
# 290                             0.000000                        13
# 291                             0.545455                        11
#
#      Aantal cilinders meest voorkomend (number of cilinders with most common Gleason)  \
# 0                                                    2
# 1                                                    3
# 2                                                    2
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 287                                                  3
# 288                                                  2
# 289                                                  4
# 290                                                  8
# 291                                                  5
#
#      Percentage Cilinders meest voorkomende graad  \
# 0                                        1.000000
# 1                                        0.428571
# 2                                        0.666667
# 3                                        0.800000
# 4                                        0.571429
# ..                                            ...
# 287                                      0.166667
# 288                                      0.181818
# 289                                      0.307692
# 290                                      0.615385
# 291                                      0.454545
#
#      primaire gleason ( check for colliniearity)  \
# 0                                              3
# 1                                              3
# 2                                              3
# 3                                              3
# 4                                              4
# ..                                           ...
# 287                                            4
# 288                                            4
# 289                                            3
# 290                                            3
# 291                                            3
#
#      secundaire gleason  (check collinearity)  \
# 0                                           4
# 1                                           4
# 2                                           3
# 3                                           4
# 4                                           4
# ..                                        ...
# 287                                         4
# 288                                         4
# 289                                         4
# 290                                         4
# 291                                         4
#
#      Grade group meest voorkomende graad  \
# 0                                      2
# 1                                      2
# 2                                      1
# 3                                      2
# 4                                      4
# ..                                   ...
# 287                                    4
# 288                                    4
# 289                                    2
# 290                                    2
# 291                                    2
#
#      Grootste diameter (percentage of tumor)  Grootste mm aantasting (mms)  \
# 0                                       64.3                           9.0
# 1                                       50.0                           2.0
# 2                                       75.0                           3.0
# 3                                       91.0                          10.0
# 4                                       83.0                           9.0
# ..                                       ...                           ...
# 287                                     30.0                           4.0
# 288                                     60.0                           9.0
# 289                                     54.0                           7.0
# 290                                     73.0                           8.0
# 291                                     93.0                          14.0
#
#      Primaire  Secundaire  Grade group Grootste mm aantasting  \
# 0           3           4                                   2
# 1           3           4                                   2
# 2           3           3                                   1
# 3           3           4                                   2
# 4           4           4                                   4
# ..        ...         ...                                 ...
# 287         4           4                                   4
# 288         4           4                                   4
# 289         3           4                                   2
# 290         3           4                                   2
# 291         4           3                                   3
#
#      Primaire Gleason.1  Secundaire Gleason.1  Grade Group  pN
# 0                     4                     4            4   0
# 1                     4                     4            4   0
# 2                     3                     3            1   0
# 3                     4                     3            3   1
# 4                     4                     3            3   0
# ..                  ...                   ...          ...  ..
# 287                   3                     4            2   0
# 288                   4                     3            3   0
# 289                   4                     3            3   0
# 290                   3                     4            2   0
# 291                   4                     5            5   0
#
# [292 rows x 35 columns]

# %%
encoder1 = OrderedLabelEncoder(order=['1c', '2a', '2b', '2c', '3a', '3b', '4']) # label as [0,1,2,3,4,5,6], no need to set ordered=True
dataset = encoder1.fit_transform(dataset1,"cT(MRI)")
dataset
# Out:
#      eadnr (I)        Age  Multifocaal  \
# 0     89869416  45.408219            0
# 1     89208722  72.849315            0
# 2     88443783  60.191781            1
# 3     88426499  66.857534            0
# 4     88408455  72.002740            1
# ..         ...        ...          ...
# 287   60261557  60.890411            0
# 288   60260249  63.279452            0
# 289   60252811  51.356164            1
# 290   60097736  58.643836            0
# 291   60070627  57.101370            0
#
#      1c (0) - Perifeer (1) -  Beide (2) - Transitie (3)  Preoperatief PSA  \
# 0                                                    1               2.64
# 1                                                    3              11.04
# 2                                                    2              15.00
# 3                                                    1               3.50
# 4                                                    1              19.80
# ..                                                 ...                ...
# 287                                                  1              10.60
# 288                                                  1               4.66
# 289                                                  1               7.11
# 290                                                  1               7.50
# 291                                                  1              34.20
#
#      Aantal zones positive percentage  Primaire Gleason  Secundaire Gleason  \
# 0                            1.000000                 3                   4
# 1                            0.333333                 3                   4
# 2                            0.833333                 3                   3
# 3                            0.666667                 3                   4
# 4                            0.250000                 4                   4
# ..                                ...               ...                 ...
# 287                          0.100000                 4                   4
# 288                          0.181818                 4                   4
# 289                          0.500000                 3                   4
# 290                          0.500000                 3                   4
# 291                          0.700000                 4                   5
#
#      Grade group (highest)  Target biopsie Core length (perc)  \
# 0                        2                               64.3
# 1                        2                               50.0
# 2                        1                               75.0
# 3                        2                               91.0
# 4                        4                               83.0
# ..                     ...                                ...
# 287                      4                               30.0
# 288                      4                               60.0
# 289                      2                               54.0
# 290                      2                               73.0
# 291                      5                               92.0
#
#      Target biopsie Core length (mm)  TargetBiopsie Primaire Gleason  \
# 0                                9.0                               3
# 1                                2.0                               3
# 2                                3.0                               3
# 3                               10.0                               3
# 4                                9.0                               4
# ..                               ...                             ...
# 287                              4.0                               4
# 288                              9.0                               4
# 289                              7.0                               3
# 290                              8.0                               3
# 291                             11.0                               4
#
#      Target Biopsie Secundaire Gleason  Grade Group (longest)  \
# 0                                    4                      2
# 1                                    4                      2
# 2                                    3                      1
# 3                                    4                      2
# 4                                    4                      4
# ..                                 ...                    ...
# 287                                  4                      4
# 288                                  4                      4
# 289                                  4                      2
# 290                                  4                      2
# 291                                  5                      5
#
#      Totaal Cilinders hoogste Graad  Percentage Cilinders hoogste graad  \
# 0                                 2                            1.000000
# 1                                 3                            0.428571
# 2                                 2                            0.666667
# 3                                 4                            0.800000
# 4                                 4                            0.571429
# ..                              ...                                 ...
# 287                               3                            0.166667
# 288                               2                            0.181818
# 289                               4                            0.307692
# 290                               8                            0.615385
# 291                               2                            0.181818
#
#      Totaal positieve cilinders  Percentage positieve cilinders  \
# 0                             2                        1.000000
# 1                             3                        0.428571
# 2                             2                        0.666667
# 3                             4                        0.800000
# 4                             4                        0.571429
# ..                          ...                             ...
# 287                           3                        0.166667
# 288                           2                        0.181818
# 289                           6                        0.461538
# 290                           8                        0.615385
# 291                           8                        0.727273
#
#      Percentage Cilinders lagere graad    Aantal cilinders neg+pos  \
# 0                               0.000000                         2
# 1                               0.000000                         7
# 2                               0.000000                         3
# 3                               0.000000                         5
# 4                               0.000000                         7
# ..                                   ...                       ...
# 287                             0.000000                        18
# 288                             0.000000                        11
# 289                             0.153846                        13
# 290                             0.000000                        13
# 291                             0.545455                        11
#
#      Aantal cilinders meest voorkomend (number of cilinders with most common Gleason)  \
# 0                                                    2
# 1                                                    3
# 2                                                    2
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 287                                                  3
# 288                                                  2
# 289                                                  4
# 290                                                  8
# 291                                                  5
#
#      Percentage Cilinders meest voorkomende graad  \
# 0                                        1.000000
# 1                                        0.428571
# 2                                        0.666667
# 3                                        0.800000
# 4                                        0.571429
# ..                                            ...
# 287                                      0.166667
# 288                                      0.181818
# 289                                      0.307692
# 290                                      0.615385
# 291                                      0.454545
#
#      primaire gleason ( check for colliniearity)  \
# 0                                              3
# 1                                              3
# 2                                              3
# 3                                              3
# 4                                              4
# ..                                           ...
# 287                                            4
# 288                                            4
# 289                                            3
# 290                                            3
# 291                                            3
#
#      secundaire gleason  (check collinearity)  \
# 0                                           4
# 1                                           4
# 2                                           3
# 3                                           4
# 4                                           4
# ..                                        ...
# 287                                         4
# 288                                         4
# 289                                         4
# 290                                         4
# 291                                         4
#
#      Grade group meest voorkomende graad  \
# 0                                      2
# 1                                      2
# 2                                      1
# 3                                      2
# 4                                      4
# ..                                   ...
# 287                                    4
# 288                                    4
# 289                                    2
# 290                                    2
# 291                                    2
#
#      Grootste diameter (percentage of tumor)  Grootste mm aantasting (mms)  \
# 0                                       64.3                           9.0
# 1                                       50.0                           2.0
# 2                                       75.0                           3.0
# 3                                       91.0                          10.0
# 4                                       83.0                           9.0
# ..                                       ...                           ...
# 287                                     30.0                           4.0
# 288                                     60.0                           9.0
# 289                                     54.0                           7.0
# 290                                     73.0                           8.0
# 291                                     93.0                          14.0
#
#      Primaire  Secundaire  Grade group Grootste mm aantasting  \
# 0           3           4                                   2
# 1           3           4                                   2
# 2           3           3                                   1
# 3           3           4                                   2
# 4           4           4                                   4
# ..        ...         ...                                 ...
# 287         4           4                                   4
# 288         4           4                                   4
# 289         3           4                                   2
# 290         3           4                                   2
# 291         4           3                                   3
#
#      Primaire Gleason.1  Secundaire Gleason.1  Grade Group  pN  cT(MRI)
# 0                     4                     4            4   0        1
# 1                     4                     4            4   0        1
# 2                     3                     3            1   0        4
# 3                     4                     3            3   1        4
# 4                     4                     3            3   0        4
# ..                  ...                   ...          ...  ..      ...
# 287                   3                     4            2   0        4
# 288                   4                     3            3   0        4
# 289                   4                     3            3   0        1
# 290                   3                     4            2   0        6
# 291                   4                     5            5   0        5
#
# [292 rows x 35 columns]

# %% [markdown]
# ## 2. Analyze data

# %%
#data types of each attribute
dataset.dtypes
# Out:
# eadnr (I)                                                                             int64
# Age                                                                                 float64
# Multifocaal                                                                           int64
# 1c (0) - Perifeer (1) -  Beide (2) - Transitie (3)                                    int64
# Preoperatief PSA                                                                    float64
# Aantal zones positive percentage                                                    float64
# Primaire Gleason                                                                      int64
# Secundaire Gleason                                                                    int64
# Grade group (highest)                                                                 int64
# Target biopsie Core length (perc)                                                   float64
# Target biopsie Core length (mm)                                                     float64
# TargetBiopsie Primaire Gleason                                                        int64
# Target Biopsie Secundaire Gleason                                                     int64
# Grade Group (longest)                                                                 int64
# Totaal Cilinders hoogste Graad                                                        int64
# Percentage Cilinders hoogste graad                                                  float64
# Totaal positieve cilinders                                                            int64
# Percentage positieve cilinders                                                      float64
# Percentage Cilinders lagere graad                                                   float64
# Aantal cilinders neg+pos                                                              int64
# Aantal cilinders meest voorkomend (number of cilinders with most common Gleason)      int64
# Percentage Cilinders meest voorkomende graad                                        float64
# primaire gleason ( check for colliniearity)                                           int64
# secundaire gleason  (check collinearity)                                              int64
# Grade group meest voorkomende graad                                                   int64
# Grootste diameter (percentage of tumor)                                             float64
# Grootste mm aantasting (mms)                                                        float64
# Primaire                                                                              int64
# Secundaire                                                                            int64
# Grade group Grootste mm aantasting                                                    int64
# Primaire Gleason.1                                                                    int64
# Secundaire Gleason.1                                                                  int64
# Grade Group                                                                           int64
# pN                                                                                    int64
# cT(MRI)                                                                               int64
# dtype: object

# %%
categorical_cols = ["cT(MRI)","Multifocaal", "pN", "1c (0) - Perifeer (1) -  Beide (2) - Transitie (3)"]
dataset.shape
# Out:
# (292, 35)

# %%
#summarize the distribution of each attribute
pd.set_option("display.max_columns", 100)
dataset.describe()
# Out:
#           eadnr (I)         Age  Multifocaal  \
# count  2.920000e+02  292.000000   292.000000
# mean   7.603276e+07   64.853669     0.352740
# std    9.581642e+06    6.504979     0.478643
# min    6.007063e+07   41.136986     0.000000
# 25%    7.005241e+07   60.535616     0.000000
# 50%    7.698776e+07   65.736986     0.000000
# 75%    8.478563e+07   69.938356     1.000000
# max    8.998303e+07   76.824658     1.000000
#
#        1c (0) - Perifeer (1) -  Beide (2) - Transitie (3)  Preoperatief PSA  \
# count                                         292.000000         292.000000
# mean                                            1.609589          10.820685
# std                                             0.840334          14.127504
# min                                             0.000000           0.430000
# 25%                                             1.000000           5.597500
# 50%                                             1.000000           8.000000
# 75%                                             2.000000          11.550000
# max                                             3.000000         190.600000
#
#        Aantal zones positive percentage  Primaire Gleason  Secundaire Gleason  \
# count                        292.000000        292.000000          292.000000
# mean                           0.585301          3.585616            3.866438
# std                            0.307304          0.552593            0.678058
# min                            0.083333          3.000000            3.000000
# 25%                            0.300000          3.000000            3.000000
# 50%                            0.500000          4.000000            4.000000
# 75%                            1.000000          4.000000            4.000000
# max                            1.000000          5.000000            5.000000
#
#        Grade group (highest)  Target biopsie Core length (perc)  \
# count             292.000000                         292.000000
# mean                3.041096                          64.335788
# std                 1.141993                          27.434954
# min                 1.000000                           7.000000
# 25%                 2.000000                          41.675000
# 50%                 3.000000                          70.915000
# 75%                 4.000000                          88.225000
# max                 5.000000                         100.000000
#
#        Target biopsie Core length (mm)  TargetBiopsie Primaire Gleason  \
# count                       292.000000                      292.000000
# mean                          7.813356                        3.585616
# std                           3.741693                        0.540013
# min                           1.000000                        3.000000
# 25%                           5.000000                        3.000000
# 50%                           8.000000                        4.000000
# 75%                          10.000000                        4.000000
# max                          17.000000                        5.000000
#
#        Target Biopsie Secundaire Gleason  Grade Group (longest)  \
# count                         292.000000             292.000000
# mean                            3.876712               3.041096
# std                             0.687547               1.141993
# min                             3.000000               1.000000
# 25%                             3.000000               2.000000
# 50%                             4.000000               3.000000
# 75%                             4.000000               4.000000
# max                             5.000000               5.000000
#
#        Totaal Cilinders hoogste Graad  Percentage Cilinders hoogste graad  \
# count                      292.000000                          292.000000
# mean                         3.160959                            0.402063
# std                          2.155019                            0.305305
# min                          1.000000                            0.045455
# 25%                          2.000000                            0.166667
# 50%                          3.000000                            0.289916
# 75%                          4.000000                            0.600000
# max                         16.000000                            1.000000
#
#        Totaal positieve cilinders  Percentage positieve cilinders  \
# count                  292.000000                      292.000000
# mean                     5.195205                        0.581350
# std                      2.776852                        0.275053
# min                      1.000000                        0.045455
# 25%                      3.000000                        0.373355
# 50%                      5.000000                        0.563492
# 75%                      7.000000                        0.779762
# max                     16.000000                        1.000000
#
#        Percentage Cilinders lagere graad    Aantal cilinders neg+pos  \
# count                           292.000000                292.000000
# mean                              0.179287                 10.205479
# std                               0.212953                  4.492709
# min                               0.000000                  1.000000
# 25%                               0.000000                  6.000000
# 50%                               0.090909                 11.500000
# 75%                               0.333333                 13.000000
# max                               0.833333                 22.000000
#
#        Aantal cilinders meest voorkomend (number of cilinders with most common Gleason)  \
# count                                         292.000000
# mean                                            3.835616
# std                                             2.147571
# min                                             1.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             5.000000
# max                                            16.000000
#
#        Percentage Cilinders meest voorkomende graad  \
# count                                    292.000000
# mean                                       0.462679
# std                                        0.283042
# min                                        0.045455
# 25%                                        0.250000
# 50%                                        0.384615
# 75%                                        0.666667
# max                                        1.000000
#
#        primaire gleason ( check for colliniearity)  \
# count                                   292.000000
# mean                                      3.417808
# std                                       0.527679
# min                                       3.000000
# 25%                                       3.000000
# 50%                                       3.000000
# 75%                                       4.000000
# max                                       5.000000
#
#        secundaire gleason  (check collinearity)  \
# count                                292.000000
# mean                                   3.811644
# std                                    0.622158
# min                                    3.000000
# 25%                                    3.000000
# 50%                                    4.000000
# 75%                                    4.000000
# max                                    5.000000
#
#        Grade group meest voorkomende graad  \
# count                           292.000000
# mean                              2.647260
# std                               1.167527
# min                               1.000000
# 25%                               2.000000
# 50%                               2.000000
# 75%                               3.000000
# max                               5.000000
#
#        Grootste diameter (percentage of tumor)  Grootste mm aantasting (mms)  \
# count                               292.000000                    292.000000
# mean                                 69.588527                      8.650685
# std                                  24.416905                      3.578943
# min                                   7.000000                      1.000000
# 25%                                  50.000000                      6.000000
# 50%                                  74.350000                      9.000000
# 75%                                  92.000000                     11.000000
# max                                 100.000000                     20.000000
#
#          Primaire  Secundaire  Grade group Grootste mm aantasting  \
# count  292.000000  292.000000                          292.000000
# mean     3.486301    3.828767                            2.815068
# std      0.540285    0.661765                            1.163615
# min      3.000000    3.000000                            1.000000
# 25%      3.000000    3.000000                            2.000000
# 50%      3.000000    4.000000                            3.000000
# 75%      4.000000    4.000000                            4.000000
# max      5.000000    5.000000                            5.000000
#
#        Primaire Gleason.1  Secundaire Gleason.1  Grade Group          pN  \
# count          292.000000            292.000000   292.000000  292.000000
# mean             3.506849              3.787671     2.797945    0.143836
# std              0.552987              0.628191     1.076265    0.351525
# min              3.000000              3.000000     1.000000    0.000000
# 25%              3.000000              3.000000     2.000000    0.000000
# 50%              3.000000              4.000000     3.000000    0.000000
# 75%              4.000000              4.000000     3.000000    0.000000
# max              5.000000              5.000000     5.000000    1.000000
#
#           cT(MRI)
# count  292.000000
# mean     3.136986
# std      1.562578
# min      0.000000
# 25%      1.000000
# 50%      4.000000
# 75%      4.000000
# max      6.000000

# %% [markdown]
# ## 3. Data visualization

# %%
for col in dataset.columns :
    # Multiple box plots on one Axes
    data = dataset[col]
    if col in categorical_cols :
        data = data.astype("category").cat.codes
    fig, ax = plt.subplots()
    ax.boxplot(data)
    ax.set_title(col)

# %%
for col in dataset.columns :
    # Multiple box plots on one Axes
    data = dataset[col]
    if col in categorical_cols :
        data = data.astype("category").cat.codes
    fig, ax = plt.subplots()
    ax.hist(data, density=False, histtype='bar')
    ax.set_title(col)

# %%
#Correlation matrix
pd.set_option("display.max_columns", 100)
pyplot.figure(figsize=(20,10))
cors = abs(dataset.corr(method='pearson'))
seaborn.heatmap(cors, mask=np.triu(np.ones_like(cors, dtype=bool)), vmin=0, vmax=1, cmap='Blues', annot=True)
pyplot.show()

# %% [markdown]
# ## 4. Edit data

# %%
for col in dataset.columns :
    if not dataset[col].isnull().values.any() :
        print(col, ':', 'NO NaN values')
    else :
        print(col, ':', 'NaN values finded')
        print('Number of NaN values: ', dataset[col].isnull().sum())
# Out:
# eadnr (I) : NO NaN values
# Age : NO NaN values
# Multifocaal : NO NaN values
# 1c (0) - Perifeer (1) -  Beide (2) - Transitie (3) : NO NaN values
# Preoperatief PSA : NO NaN values
# Aantal zones positive percentage : NO NaN values
# Primaire Gleason : NO NaN values
# Secundaire Gleason : NO NaN values
# Grade group (highest) : NO NaN values
# Target biopsie Core length (perc) : NO NaN values
# Target biopsie Core length (mm) : NO NaN values
# TargetBiopsie Primaire Gleason : NO NaN values
# Target Biopsie Secundaire Gleason : NO NaN values
# Grade Group (longest) : NO NaN values
# Totaal Cilinders hoogste Graad : NO NaN values
# Percentage Cilinders hoogste graad : NO NaN values
# Totaal positieve cilinders : NO NaN values
# Percentage positieve cilinders : NO NaN values
# Percentage Cilinders lagere graad   : NO NaN values
# Aantal cilinders neg+pos : NO NaN values
# Aantal cilinders meest voorkomend (number of cilinders with most common Gleason) : NO NaN values
# Percentage Cilinders meest voorkomende graad : NO NaN values
# primaire gleason ( check for colliniearity) : NO NaN values
# secundaire gleason  (check collinearity) : NO NaN values
# Grade group meest voorkomende graad : NO NaN values
# Grootste diameter (percentage of tumor) : NO NaN values
# Grootste mm aantasting (mms) : NO NaN values
# Primaire : NO NaN values
# Secundaire : NO NaN values
# Grade group Grootste mm aantasting : NO NaN values
# Primaire Gleason.1 : NO NaN values
# Secundaire Gleason.1 : NO NaN values
# Grade Group : NO NaN values
# pN : NO NaN values
# cT(MRI) : NO NaN values

# %%
#quick look at the breakdown of class values
for col in categorical_cols :
    dataset[col] = dataset[col].astype('category')
    print('###########################')
    print(dataset.groupby(col).size())
# Out:
# ###########################
# cT(MRI)
# 0      5
# 1     83
# 2      1
# 3     28
# 4    139
# 5     25
# 6     11
# dtype: int64
# ###########################
# Multifocaal
# 0    189
# 1    103
# dtype: int64
# ###########################
# pN
# 0    250
# 1     42
# dtype: int64
# ###########################
# 1c (0) - Perifeer (1) -  Beide (2) - Transitie (3)
# 0      5
# 1    167
# 2     57
# 3     63
# dtype: int64

# %% [markdown]
# ## 5. Data split (train and test)

# %%
from sklearn.model_selection import train_test_split

# %%
#Split data indixes in train and test
idx_train, idx_test = train_test_split(dataset.index.tolist(), train_size=0.8, random_state=42, shuffle=True)
print('Train data length: ', len(idx_train))
print('Test data length: ', len(idx_test))
print('Total data length: ', len(idx_train) + len(idx_test))
# Out:
# Train data length:  233
# Test data length:  59
# Total data length:  292

# %%
#Select train data and save locally
train_data = dataset.loc[idx_train]
train_data.to_csv('Dataset_cedric/Train.csv', index=False)
#Select test data and save locally
test_data = dataset.loc[idx_test]
test_data.to_csv('Dataset_cedric/Test.csv', index=False)
print('Train data size: ', train_data.shape)
print('Test data length: ', test_data.shape)
# Out:
# Train data size:  (233, 35)
# Test data length:  (59, 35)

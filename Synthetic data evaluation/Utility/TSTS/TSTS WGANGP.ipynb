# %% [markdown]
# # TSTR WGANGP

# %%
#import libraries
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import os
print('Libraries imported!!')
# Out:
# Libraries imported!!

# %%
#define directory of functions and actual directory
HOME_PATH = 'C:/Users/27261/Desktop/prostate/code-0126/'
FUNCTIONS_DIR = 'EVALUATION FUNCTIONS/UTILITY'
ACTUAL_DIR = os.getcwd()

#change directory to functions directory
os.chdir(HOME_PATH + FUNCTIONS_DIR)

#import functions for data labelling analisys
from utility_evaluation import DataPreProcessor
from utility_evaluation import train_evaluate_model

#change directory to actual directory
os.chdir(ACTUAL_DIR)
print('Functions imported!!')
# Out:
# Functions imported!!

# %% [markdown]
# ## 1. Read data

# %%
#read real dataset
train_data = pd.read_csv(HOME_PATH + 'Dataset_cedric/SYNTHETIC DATASETS/WGANGP.csv')
categorical_columns = ["cT(MRI)","Multifocaal", "pN", "1c (0) - Perifeer (1) -  Beide (2) - Transitie (3)"]
for col in categorical_columns :
    train_data[col] = train_data[col].astype('category')
train_data
# Out:
#      eadnr (I)        Age Multifocaal  \
# 0     67360704  55.632397           0
# 1     66874764  52.770901           0
# 2     66687892  54.142345           0
# 3     69780672  58.598602           0
# 4     66684832  54.072430           0
# ..         ...        ...         ...
# 228   70849336  54.636955           0
# 229   68792168  54.218044           0
# 230   69266968  57.274818           0
# 231   68060080  56.961246           0
# 232   70741688  56.654839           0
#
#     1c (0) - Perifeer (1) -  Beide (2) - Transitie (3)  Preoperatief PSA  \
# 0                                                    1         16.042311
# 1                                                    1         19.027332
# 2                                                    1         20.480595
# 3                                                    1         14.343013
# 4                                                    1          5.600604
# ..                                                 ...               ...
# 228                                                  1         10.592919
# 229                                                  1         -9.360442
# 230                                                  1         -0.832032
# 231                                                  1          4.401272
# 232                                                  1          2.127598
#
#      Aantal zones positive percentage  Primaire Gleason  Secundaire Gleason  \
# 0                           -0.061713                 3                   3
# 1                            0.057281                 3                   2
# 2                           -0.009403                 3                   3
# 3                           -0.080210                 3                   3
# 4                            0.023530                 3                   2
# ..                                ...               ...                 ...
# 228                          0.074774                 3                   2
# 229                          0.061045                 3                   3
# 230                          0.050229                 3                   2
# 231                         -0.060569                 3                   2
# 232                         -0.036717                 3                   3
#
#      Grade group (highest)  Target biopsie Core length (perc)  ...  \
# 0                        2                          50.874027  ...
# 1                        2                          47.970814  ...
# 2                        2                          53.226791  ...
# 3                        2                          61.369087  ...
# 4                        2                          47.753101  ...
# ..                     ...                                ...  ...
# 228                      2                          62.640102  ...
# 229                      2                          52.218075  ...
# 230                      2                          62.431156  ...
# 231                      2                          59.421577  ...
# 232                      2                          63.332634  ...
#
#      Grootste diameter (percentage of tumor)  Grootste mm aantasting (mms)  \
# 0                                  69.842308                      3.186382
# 1                                  52.340023                      1.464574
# 2                                  51.009029                      3.261557
# 3                                  64.289185                      2.490963
# 4                                  50.606117                      1.494166
# ..                                       ...                           ...
# 228                                70.276543                      2.687879
# 229                                53.375885                      2.209548
# 230                                63.008644                      3.394243
# 231                                58.368599                      1.935508
# 232                                65.631523                      1.548735
#
#      Primaire  Secundaire  Grade group Grootste mm aantasting  \
# 0           3           2                                   1
# 1           3           2                                   1
# 2           3           2                                   1
# 3           3           2                                   1
# 4           3           2                                   1
# ..        ...         ...                                 ...
# 228         3           2                                   1
# 229         3           2                                   1
# 230         3           2                                   1
# 231         3           2                                   1
# 232         3           2                                   1
#
#      Primaire Gleason.1  Secundaire Gleason.1  Grade Group  pN  cT(MRI)
# 0                     3                     3            1   0        4
# 1                     3                     3            1   0        4
# 2                     3                     3            1   0        4
# 3                     3                     3            1   1        4
# 4                     3                     3            1   0        4
# ..                  ...                   ...          ...  ..      ...
# 228                   3                     3            1   0        1
# 229                   3                     3            1   0        1
# 230                   3                     3            1   1        4
# 231                   3                     3            1   0        4
# 232                   3                     3            1   0        4
#
# [233 rows x 35 columns]

# %%
#read test data
test_data = pd.read_csv(HOME_PATH + 'Dataset_cedric/SYNTHETIC DATASETS/WGANGP-2.csv')
for col in categorical_columns :
    test_data[col] = test_data[col].astype('category')
test_data
# Out:
#      eadnr (I)        Age Multifocaal  \
# 0     84676824  50.961609           1
# 1     85140512  49.929680           1
# 2     82776768  51.593681           1
# 3     79681856  51.603085           1
# 4     91650728  52.424927           1
# ..         ...        ...         ...
# 228   86623320  49.475887           1
# 229   91095632  53.629219           1
# 230   84774328  52.749996           1
# 231   73967840  48.766918           1
# 232   81500184  50.055408           1
#
#     1c (0) - Perifeer (1) -  Beide (2) - Transitie (3)  Preoperatief PSA  \
# 0                                                    2         46.835880
# 1                                                    2         61.010914
# 2                                                    2         74.331558
# 3                                                    2         48.577232
# 4                                                    2         71.156456
# ..                                                 ...               ...
# 228                                                  2         77.816917
# 229                                                  2         62.161751
# 230                                                  2         45.923435
# 231                                                  2         53.256252
# 232                                                  2         63.542850
#
#      Aantal zones positive percentage  Primaire Gleason  Secundaire Gleason  \
# 0                            0.527339                 4                   2
# 1                            0.403266                 4                   3
# 2                            0.407112                 4                   3
# 3                            0.329649                 4                   2
# 4                            0.587035                 4                   2
# ..                                ...               ...                 ...
# 228                          0.503106                 4                   3
# 229                          0.531124                 4                   3
# 230                          0.443878                 4                   3
# 231                          0.323729                 3                   3
# 232                          0.428498                 4                   3
#
#      Grade group (highest)  Target biopsie Core length (perc)  ...  \
# 0                        3                          60.061768  ...
# 1                        3                          66.329971  ...
# 2                        3                          65.345901  ...
# 3                        3                          55.110153  ...
# 4                        3                          72.364830  ...
# ..                     ...                                ...  ...
# 228                      4                          74.210953  ...
# 229                      3                          77.162560  ...
# 230                      3                          76.847176  ...
# 231                      2                          34.650719  ...
# 232                      3                          62.004131  ...
#
#      Grootste diameter (percentage of tumor)  Grootste mm aantasting (mms)  \
# 0                                  88.971870                      4.173984
# 1                                  72.500710                      2.864784
# 2                                  72.027702                      3.719828
# 3                                  63.349052                      4.366672
# 4                                  93.178192                      5.079518
# ..                                       ...                           ...
# 228                                96.076668                      6.584691
# 229                                91.371986                      4.476023
# 230                                78.070107                      4.614897
# 231                                52.821392                      2.717286
# 232                                72.887428                      4.143359
#
#      Primaire  Secundaire  Grade group Grootste mm aantasting  \
# 0           3           3                                   2
# 1           3           3                                   1
# 2           2           3                                   2
# 3           3           3                                   2
# 4           3           3                                   2
# ..        ...         ...                                 ...
# 228         2           3                                   2
# 229         2           3                                   2
# 230         3           3                                   2
# 231         2           3                                   1
# 232         3           3                                   1
#
#      Primaire Gleason.1  Secundaire Gleason.1  Grade Group  pN  cT(MRI)
# 0                     3                     3            2   0        1
# 1                     3                     3            2   0        4
# 2                     3                     3            2   0        4
# 3                     3                     3            2   0        1
# 4                     3                     3            3   0        4
# ..                  ...                   ...          ...  ..      ...
# 228                   3                     3            2   0        4
# 229                   3                     2            2   0        4
# 230                   3                     3            2   0        4
# 231                   3                     3            2   0        4
# 232                   3                     3            2   0        4
#
# [233 rows x 35 columns]

# %%
target = 'pN'
#quick look at the breakdown of class values
print('Train data')
print(train_data.shape)
print(train_data.groupby(target).size())
print('#####################################')
print('Test data')
print(test_data.shape)
print(test_data.groupby(target).size())
# Out:
# Train data
# (233, 35)
# pN
# 0    125
# 1    108
# dtype: int64
# #####################################
# Test data
# (233, 35)
# pN
# 0    233
# dtype: int64

# %% [markdown]
# ## 2. Pre-process training data

# %%
target = "pN"
categorical_columns = ["cT(MRI)","Multifocaal", "1c (0) - Perifeer (1) -  Beide (2) - Transitie (3)"]
numerical_columns = numerical_columns = train_data.select_dtypes(include=['int64']).columns.tolist()
categories = [np.array(range(7)), np.array(range(2)), np.array(range(4))]

data_preprocessor = DataPreProcessor(categorical_columns, numerical_columns, categories)
x_train = data_preprocessor.preprocess_train_data(train_data.loc[:, train_data.columns != target])
y_train = train_data.loc[:, target]

x_train.shape, y_train.shape
# Out:
# ((233, 33), (233,))

# %% [markdown]
# ## 3. Preprocess test data

# %%
x_test = data_preprocessor.preprocess_test_data(test_data.loc[:, test_data.columns != target])
y_test = test_data.loc[:, target]
x_test.shape, y_test.shape
# Out:
# ((233, 33), (233,))

# %% [markdown]
# ## 4. Create a dataset to save the results

# %%
results = pd.DataFrame(columns = ['model','accuracy','precision','recall','f1'])
results
# Out:
# Empty DataFrame
# Columns: [model, accuracy, precision, recall, f1]
# Index: []

# %% [markdown]
# ## 4. Train and evaluate Random Forest Classifier

# %%
rf_results = train_evaluate_model('RF', x_train, y_train, x_test, y_test)
results = pd.concat([results, rf_results], ignore_index=True)
rf_results
# Out:
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.1s finished
# [Parallel(n_jobs=3)]: Using backend ThreadingBackend with 3 concurrent workers.
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=3)]: Done 100 out of 100 | elapsed:    0.0s finished
#   model  accuracy  precision  recall      f1
# 0    RF    0.1159        1.0  0.1159  0.2077

# %% [markdown]
# ## 5. Train and Evaluate KNeighbors Classifier

# %%
knn_results = train_evaluate_model('KNN', x_train, y_train, x_test, y_test)
results = pd.concat([results, knn_results], ignore_index=True)
knn_results
# Out:
#   model  accuracy  precision  recall      f1
# 0   KNN    0.9142        1.0  0.9142  0.9552

# %% [markdown]
# ## 6. Train and evaluate Decision Tree Classifier

# %%
dt_results = train_evaluate_model('DT', x_train, y_train, x_test, y_test)
results = pd.concat([results, dt_results], ignore_index=True)
dt_results
# Out:
#   model  accuracy  precision  recall      f1
# 0    DT    0.9528        1.0  0.9528  0.9758

# %% [markdown]
# ## 7. Train and evaluate Support Vector Machines Classifier

# %%
svm_results = train_evaluate_model('SVM', x_train, y_train, x_test, y_test)
results = pd.concat([results, svm_results], ignore_index=True)
svm_results
# Out:
# [LibSVM]
#   model  accuracy  precision  recall      f1
# 0   SVM    0.7725        1.0  0.7725  0.8717

# %% [markdown]
# ## 8. Train and evaluate Multilayer Perceptron Classifier

# %%
mlp_results = train_evaluate_model('MLP', x_train, y_train, x_test, y_test)
results = pd.concat([results, mlp_results], ignore_index=True)
mlp_results
# Out:
# Iteration 1, loss = 0.67965270
# Iteration 180, loss = 0.13173528
# Iteration 181, loss = 0.12928841
# Iteration 182, loss = 0.12905769
# Iteration 183, loss = 0.13149175
# Iteration 184, loss = 0.13559919
# Iteration 185, loss = 0.13702535
# Iteration 186, loss = 0.12350355
# Iteration 187, loss = 0.13616724
# Iteration 188, loss = 0.14572924
# Iteration 189, loss = 0.12241568
# Iteration 190, loss = 0.13252034
# Iteration 191, loss = 0.12920838
# Iteration 192, loss = 0.12270564
# Iteration 193, loss = 0.13013258
# Iteration 194, loss = 0.12626292
# Iteration 195, loss = 0.11723641
# Iteration 196, loss = 0.12681568
# Iteration 197, loss = 0.15852438
# Iteration 198, loss = 0.14952570
# Iteration 199, loss = 0.12114423
# Iteration 200, loss = 0.12123418
# Iteration 201, loss = 0.11929221
# Iteration 202, loss = 0.11936417
# Iteration 203, loss = 0.12932677
# Iteration 204, loss = 0.12120698
# Iteration 205, loss = 0.11423232
# Iteration 206, loss = 0.12375809
# Iteration 207, loss = 0.12255158
# Iteration 208, loss = 0.11839470
# Iteration 209, loss = 0.11829955
# Iteration 210, loss = 0.11528767
# Iteration 211, loss = 0.11878473
# Iteration 212, loss = 0.11827739
# Iteration 213, loss = 0.10990164
# Iteration 214, loss = 0.13359157
# Iteration 215, loss = 0.11418218
# Iteration 216, loss = 0.11295945
# Iteration 217, loss = 0.13271879
# Iteration 218, loss = 0.10843123
# Iteration 219, loss = 0.10735930
# Iteration 220, loss = 0.13196288
# Iteration 221, loss = 0.12045619
# Iteration 222, loss = 0.11736986
# Iteration 223, loss = 0.13441511
# Iteration 224, loss = 0.11691878
# Iteration 225, loss = 0.10542660
# Iteration 226, loss = 0.11740789
# Iteration 227, loss = 0.11694475
# Iteration 228, loss = 0.10439843
# Iteration 229, loss = 0.10179694
# Iteration 230, loss = 0.10518801
# Iteration 231, loss = 0.10370858
# Iteration 232, loss = 0.10238657
# Iteration 233, loss = 0.10643236
# Iteration 234, loss = 0.09738235
# Iteration 235, loss = 0.09687724
# Iteration 236, loss = 0.10528767
# Iteration 237, loss = 0.10298314
# Iteration 238, loss = 0.10436271
# Iteration 239, loss = 0.10932977
# Iteration 240, loss = 0.10831232
# Iteration 241, loss = 0.09922146
# Iteration 242, loss = 0.09030346
# Iteration 243, loss = 0.09497142
# Iteration 244, loss = 0.10769314
# Iteration 245, loss = 0.10617971
# Iteration 246, loss = 0.09991552
# Iteration 247, loss = 0.09749789
# Iteration 248, loss = 0.09542023
# Iteration 249, loss = 0.09970199
# Iteration 250, loss = 0.09756654
# Iteration 251, loss = 0.09536525
# Iteration 252, loss = 0.09340859
# Iteration 253, loss = 0.09057907
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#   model  accuracy  precision  recall      f1
# 0   MLP    0.0043        1.0  0.0043  0.0085

# %% [markdown]
# ## 9. Save results file

# %%
# results.to_csv(HOME_PATH + 'RESULTS/models_results_wgangp.csv', index=False)
results
# Out:
#   model  accuracy  precision  recall      f1
# 0    RF    0.1159        1.0  0.1159  0.2077
# 1   KNN    0.9142        1.0  0.9142  0.9552
# 2    DT    0.9528        1.0  0.9528  0.9758
# 3   SVM    0.7725        1.0  0.7725  0.8717
# 4   MLP    0.0043        1.0  0.0043  0.0085
